# %%
import pandas as pd

# %%
df = pd.read_csv('/content/new_crop_yield_indianewfinal.csv')
df.head()
# Out:
#         Season  State  Annual_Rainfall  Pesticide        Yield Region  \
# 0  Whole Year   Assam           2051.4   22882.34     0.796087   West
# 1  Kharif       Assam           2051.4    2057.47     0.710435  South
# 2  Kharif       Assam           2051.4     246.76     0.238333  North
# 3  Whole Year   Assam           2051.4    6093.36  5238.051739  North
# 4  Kharif       Assam           2051.4     539.09     0.420909  South
#
#   Soil_Type     Crop  Rainfall_mm  Temperature_Celsius at 2 Meters  \
# 0     Sandy   Cotton   897.077239                        27.676966
# 1      Clay     Rice   992.673282                        18.026142
# 2      Loam   Barley   147.998025                        29.794042
# 3     Sandy  Soybean   986.866331                        16.644190
# 4      Silt    Wheat   730.379174                        31.620687
#
#    Specific Humidity at 2 Meters (g/kg)  Relative Humidity at 2 Meters (%)  \
# ...

# %%
df.isnull().sum()
# Out:
# Season                                  0
# State                                   0
# Annual_Rainfall                         0
# Pesticide                               0
# Yield                                   0
# Region                                  0
# Soil_Type                               0
# Crop                                    0
# Rainfall_mm                             0
# Temperature_Celsius at 2 Meters         0
# Specific Humidity at 2 Meters (g/kg)    0
# Relative Humidity at 2 Meters (%)       0
# Fertilizer_Used                         0
# Irrigation_Used                         0
# Weather_Condition                       0
# Days_to_Harvest                         0
# Yield_tons_per_hectare                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 17 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Season                                19689 non-null  object
#  1   State                                 19689 non-null  object
#  2   Annual_Rainfall                       19689 non-null  float64
#  3   Pesticide                             19689 non-null  float64
#  4   Yield                                 19689 non-null  float64
#  5   Region                                19689 non-null  object
#  6   Soil_Type                             19689 non-null  object
#  7   Crop                                  19689 non-null  object
#  8   Rainfall_mm                           19689 non-null  float64
#  9   Temperature_Celsius at 2 Meters       19689 non-null  float64
# ...

# %%
df['Yield_tons_per_hectare'].value_counts()
# Out:
# Yield_tons_per_hectare
# 6.555816    1
# 4.116736    1
# 3.402384    1
# 3.280013    1
# 5.658543    1
#            ..
# 5.670292    1
# 6.208749    1
# 3.853745    1
# 3.723644    1
# 2.965308    1
# Name: count, Length: 19689, dtype: int64
