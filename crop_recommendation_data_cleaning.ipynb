# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/new_crop_recommendation.csv')
df.head()
# Out:
#   Soilcolor    Ph        K       P       N     Zn       S    QV2M-W   QV2M-Sp  \
# 0     brown  6.10  226.000   4.000  0.1200  1.100  11.000  7.933333  8.403333
# 1     brown  5.90  426.000   5.000  0.2375  2.600   9.000  7.183333  7.650000
# 2     black  5.66  175.615  18.241  0.2518  2.235  21.445  7.183333  7.650000
# 3      gray  5.37  168.490   2.690  0.1639  1.900   5.780  8.910000  9.480000
# 4     brown  5.61  161.458   4.224  0.2300  1.325  12.158  7.183333  7.650000
#
#      QV2M-Su  ...  PRECTOTCORR-W  PRECTOTCORR-Sp  PRECTOTCORR-Su  \
# 0  11.413333  ...       1.763333        3.246667       13.013333
# 1  10.476667  ...       2.073333        2.613333        4.836667
# 2  10.476667  ...       2.073333        2.613333        4.836667
# 3  12.246667  ...       2.293333        4.610000       17.446667
# 4  10.476667  ...       2.073333        2.613333        4.836667
#
#    PRECTOTCORR-Au  WD10M  GWETTOP  CLOUD_AMT  WS2M_RANGE     PS   label
# 0        3.463333  88.38     0.74      59.11        6.26  76.54  Barley
# 1        3.630000  75.69     0.65       0.46       46.10  74.17  Barley
# 2        3.630000  75.69     0.65       0.46       46.10  74.17  Barley
# 3        5.803333  68.94     0.73      59.11        5.44  78.25  Barley
# 4        3.630000  75.69     0.65       0.46       46.10  74.17  Barley
#
# [5 rows x 29 columns]

# %%
df.isnull().sum()
# Out:
# Soilcolor         0
# Ph                0
# K                 0
# P                 0
# N                 0
# Zn                0
# S                 0
# QV2M-W            0
# QV2M-Sp           0
# QV2M-Su           0
# QV2M-Au           0
# T2M_MAX-W         0
# T2M_MAX-Sp        0
# T2M_MAX-Su        0
# T2M_MAX-Au        0
# T2M_MIN-W         0
# T2M_MIN-Sp        0
# T2M_MIN-Su        0
# T2M_MIN-Au        0
# PRECTOTCORR-W     0
# PRECTOTCORR-Sp    0
# PRECTOTCORR-Su    0
# PRECTOTCORR-Au    0
# WD10M             0
# GWETTOP           0
# CLOUD_AMT         0
# WS2M_RANGE        0
# PS                0
# label             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Soilcolor       4600 non-null   object
#  1   Ph              4600 non-null   float64
#  2   K               4600 non-null   float64
#  3   P               4600 non-null   float64
#  4   N               4600 non-null   float64
#  5   Zn              4600 non-null   float64
#  6   S               4600 non-null   float64
#  7   QV2M-W          4600 non-null   float64
#  8   QV2M-Sp         4600 non-null   float64
#  9   QV2M-Su         4600 non-null   float64
#  10  QV2M-Au         4600 non-null   float64
#  11  T2M_MAX-W       4600 non-null   float64
#  12  T2M_MAX-Sp      4600 non-null   float64
#  13  T2M_MAX-Su      4600 non-null   float64
#  14  T2M_MAX-Au      4600 non-null   float64
#  15  T2M_MIN-W       4600 non-null   float64
#  16  T2M_MIN-Sp      4600 non-null   float64
#  17  T2M_MIN-Su      4600 non-null   float64
#  18  T2M_MIN-Au      4600 non-null   float64
#  19  PRECTOTCORR-W   4600 non-null   float64
#  20  PRECTOTCORR-Sp  4600 non-null   float64
#  21  PRECTOTCORR-Su  4600 non-null   float64
#  22  PRECTOTCORR-Au  4600 non-null   float64
#  23  WD10M           4600 non-null   float64
#  24  GWETTOP         4600 non-null   float64
#  25  CLOUD_AMT       4600 non-null   float64
#  26  WS2M_RANGE      4600 non-null   float64
#  27  PS              4600 non-null   float64
#  28  label           4600 non-null   object
# dtypes: float64(27), object(2)
# memory usage: 1.0+ MB

# %%
df['label'].value_counts()
# Out:
# label
# Maize         600
# Teff          600
# Wheat         600
# Barley        400
# Bean          300
# Dagussa       300
# Fallow        300
# Niger seed    300
# Pea           300
# Potato        300
# Red Pepper    300
# Sorghum       300
# Name: count, dtype: int64
